# %%
import os

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## HadCRUT5 analysis time series: ensemble means and uncertainties
#
# The following files contain time series derived from the HadCRUT5 grids for selected regions. These 'best estimate' series are computed as the means of regional time series computed for each of the 200 ensemble member realisations. Time series are presented as temperature anomalies (deg C) relative to 1961-1990.
#
# https://www.metoffice.gov.uk/hadobs/hadcrut5/data/current/download.html

# %%
df = pd.read_csv(
    "/work/ch0636/eddy/pool/obs/cru/HadCRUT5/HadCRUT.5.0.2.0.analysis.summary_series.global.annual.csv"
)
workdir = os.getcwd()
df.tail()
# Out:
#      Time  Anomaly (deg C)  Lower confidence limit (2.5%)
# 169  2019         0.891073                       0.856787  \
# 170  2020         0.922921                       0.888298
# 171  2021         0.761906                       0.725458
# 172  2022         0.801305                       0.765258
# 173  2023         1.100057                       1.061392
#
#      Upper confidence limit (97.5%)
# 169                        0.925358
# 170                        0.957543
# 171                        0.798353
# 172                        0.837353
# 173                        1.138723

# %%
plt.plot("Time", "Anomaly (deg C)", data=df)
plt.xlabel("years")
plt.ylabel("Anomaly (deg C) relative to 1961-1990")
plt.title("HadCRUT.5.0.2.0.analysis.summary_series.global.annual.csv")
plt.axhline(y=0, color="grey", linestyle="-")
# plt.axvline(x = 1961, color = 'r', linestyle = ':')
# plt.axvline(x = 1990, color = 'r', linestyle = ':')
plt.axvline(x=1850, color="g", linestyle=":")
plt.axvline(x=1900, color="g", linestyle=":")
plt.axhline(y=1.1, color="r", linestyle=":")
plt.text(1852, 0.6, "Pre Industrial IPCC", size=9, color="g")
plt.text(1825, 1.07, "1.1°C", size=10, color="r")
plt.savefig(workdir + "/HadCRU_GWL_PI_1961-1990_new_version24.png", bbox_inches="tight")

# %%
# Die sollte der Wert von Kevins Studien sein
# 1961-1990 has already warmed compared to PI (1850-1900)
# mean of 1850-1900
PI_1961_90 = df[0:51].mean()
PI_1961_90  # ['Anomaly (deg C)']
# Out:
# Time                              1875.000000
# Anomaly (deg C)                     -0.356495
# Lower confidence limit (2.5%)       -0.499834
# Upper confidence limit (97.5%)      -0.213156
# dtype: float64

# %%
df = pd.read_csv(
    "/work/ch0636/eddy/pool/obs/cru/HadCRUT5/HadCRUT.5.0.2.0.analysis.summary_series.global.annual.csv"
)

dfn = df.copy()

# mean from 1971-2000
PI = dfn.query("Time >= 1850 and Time <= 1900").mean()
dfn["Anomaly (deg C)"] = dfn["Anomaly (deg C)"] - PI["Anomaly (deg C)"]

delta = dfn.query("Time >= 1971 and Time <= 2000").mean()
delta
# Out:
# Time                              1985.500000
# Anomaly (deg C)                      0.509320
# Lower confidence limit (2.5%)        0.117513
# Upper confidence limit (97.5%)       0.188138
# dtype: float64

# %% [markdown]
# This means the difference of 1971-2000 to Pre Industral is

# %%
print(
    "In HadCru the Temperature changed already in 1971-2000 compare to Pre Industrial 1850-1900 about",
    delta,
    "[deg C]",
)
# Out:
# In HadCru the Temperature changed already in 1971-2000 compare to Pre Industrial 1850-1900 about Time                              1985.500000
# Anomaly (deg C)                      0.509320
# Lower confidence limit (2.5%)        0.117513
# Upper confidence limit (97.5%)       0.188138
# dtype: float64 [deg C]

# %%
dfn.tail()
# Out:
#      Time  Anomaly (deg C)  Lower confidence limit (2.5%)
# 169  2019         1.247567                       0.856787  \
# 170  2020         1.279415                       0.888298
# 171  2021         1.118400                       0.725458
# 172  2022         1.157800                       0.765258
# 173  2023         1.456552                       1.061392
#
#      Upper confidence limit (97.5%)
# 169                        0.925358
# 170                        0.957543
# 171                        0.798353
# 172                        0.837353
# 173                        1.138723

# %%
plt.axhline(y=1.456552, color="grey", linestyle=":")
plt.axvline(x=2023, color="grey", linestyle=":")
plt.plot("Time", "Anomaly (deg C)", data=dfn)
plt.xlabel("years")
plt.ylabel("Anomaly (deg C) relative to PI: 1850-1900")
plt.title("HadCRUT.5.0.2.0.analysis.summary_series.global.annual.csv")
plt.axhline(y=0, color="grey", linestyle="-")
# plt.axvline(x = 1961, color = 'r', linestyle = ':')
# plt.axvline(x = 1990, color = 'r', linestyle = ':')
plt.axvline(x=1850, color="g", linestyle=":")
plt.axvline(x=1900, color="g", linestyle=":")

plt.text(2019, -0.5, "2023", size=9, color="r")
plt.text(1830, 1.4, "1.46", size=9, color="r")
# plt.axvline(x=1971, color="r", linestyle=":")
# plt.axvline(x=2000, color="r", linestyle=":")
plt.text(1852, 0.5, "Pre Industrial IPCC", size=9, color="g")

# plt.text(1973, 1.1, "Historical", size=9, color="r")
# plt.text(1973, 1, "+0.51 to PI", size=8, color="r")
workdir = os.getcwd()
# save plot:
plt.savefig(workdir + "/HadCRU_GWL_PI_new_version24.png", bbox_inches="tight")
